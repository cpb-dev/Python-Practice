# %% [markdown]
# <a href="https://www.kaggle.com/code/cpbdev/sequels-dataset?scriptVersionId=118969476" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Data Set Up

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

data = pd.read_csv('../input/sequels-across-genres/Movies - Cleaned.csv')
print("\n")
print(data.columns.to_list())
# Out:
# /kaggle/input/sequels-across-genres/Movies - Cleaned.csv
# /kaggle/input/sequels-across-genres/Movies with sequels.csv
#
#
# ['index', 'Title', 'Release Date', 'Year', 'Description', 'URL', 'IMDb Rating', 'Runtime (mins)', 'Genres', 'Num Votes', 'Directors', 'Movie Series', 'Order']

# %% [markdown]
# # Analysing the Use of Sequels in Cinema

# %%
import plotly.express as px

#Create dataframe for movie series (order is important here too)
sequels_year_df = data[['Year', 'Movie Series', 'Order']]

#Drop first movie
sequels_year_df.drop(sequels_year_df[sequels_year_df['Order'] == 1].index, inplace = True)
sequels_year_df.drop('Order', inplace = True, axis = 1)

#Count the number of times the year is mentioned
year_count = sequels_year_df.Year.value_counts()
year_index = year_count.index

fig = px.bar(data, x = year_index, y = year_count, title = 'Each Sequel Title Released per Year', labels={'x': 'Year', 'y':'No. Films'})
fig.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# In the above bar chart you can see the number of different movie sequels produced per year.
# For this graph, I made sure to remove the first movie of the franchise (found using the "Order" column in the database). I did this so that only the continuation of a series is recorded, as when the first movie is released a sequel isn't usually the plan.
# From this graph we can see 2011 had the most sequels produced, with 28 sequels being released.

# %% [markdown]
# # Below code is a work in progress.

# %%
genres_df = pd.concat([data['Title'], data['Genres'].str.split(',', expand = True)],axis = 1)

#Splitting all the genres from their original column
g1= pd.DataFrame(zip(genres_df[0].values.tolist(), [0]*(len(genres_df[0].values.tolist()))), columns = ['title', 'genre'])
g2= pd.DataFrame(zip(genres_df[1].values.tolist(), [1]*(len(genres_df[1].values.tolist()))), columns = ['title', 'genre'])
g3= pd.DataFrame(zip(genres_df[2].values.tolist(), [2]*(len(genres_df[2].values.tolist()))), columns = ['title', 'genre'])
g4= pd.DataFrame(zip(genres_df[3].values.tolist(), [3]*(len(genres_df[3].values.tolist()))), columns = ['title', 'genre'])
g5= pd.DataFrame(zip(genres_df[4].values.tolist(), [4]*(len(genres_df[4].values.tolist()))), columns = ['title', 'genre'])
g6= pd.DataFrame(zip(genres_df[5].values.tolist(), [5]*(len(genres_df[5].values.tolist()))), columns = ['title', 'genre'])
g7= pd.DataFrame(zip(genres_df[6].values.tolist(), [6]*(len(genres_df[6].values.tolist()))), columns = ['title', 'genre'])

#Joining all the genres together as a list
genres_all = [g1, g2, g3, g4, g5, g6, g7]

#Concatinating all the genres to one DataFrame
newgenre_df = pd.concat(genres_all)

#Counting the genre values
genreCount = newgenre_df['title'].value_counts().values
genreIndex = newgenre_df['title'].value_counts().index

#Creatingthe pie chart
fig = px.pie(newgenre_df, values = genreCount, names = genreIndex, title = "Genres with Most Sequels Pie Chart")
fig.show()
# Out:
# <div>                            <div id="6a713ae3-f8be-4a7c-a52d-0e76b513792c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a713ae3-f8be-4a7c-a52d-0e76b513792c")) {                    Plotly.newPlot(                        "6a713ae3-f8be-4a7c-a52d-0e76b513792c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Action"," Thriller"," Adventure"," Sci-Fi"," Comedy"," Fantasy"," Family"," Crime","Comedy","Horror"," Mystery"," Horror"," Drama"," Romance","Animation","Adventure","Drama","Crime"," Sport"," Music"," Musical","Fantasy"," Action"," War"," Western","Mystery"," Biography"," History","Biography","Sci-Fi"],"legendgroup":"","name":"","showlegend":true,
# ...

# %% [markdown]
# In this pie chart the genres for each of the movies within the sequel dataset are split from the original genre column and counted separately as to count genres singularly rather than multiple mixed genres being counted together.
