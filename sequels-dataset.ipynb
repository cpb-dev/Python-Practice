# %% [markdown]
# <a href="https://www.kaggle.com/code/cpbdev/sequels-dataset?scriptVersionId=118868369" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Data Set Up

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

data = pd.read_csv('../input/sequels-across-genres/Movies - Cleaned.csv')
print("\n")
print(data.columns.to_list())
# Out:
# /kaggle/input/sequels-across-genres/Movies - Cleaned.csv
# /kaggle/input/sequels-across-genres/Movies with sequels.csv
#
#
# ['index', 'Title', 'Release Date', 'Year', 'Description', 'URL', 'IMDb Rating', 'Runtime (mins)', 'Genres', 'Num Votes', 'Directors', 'Movie Series', 'Order']

# %% [markdown]
# # Analysing the Use of Sequels in Cinema

# %%
import plotly.express as px

#Create dataframe for movie series (order is important here too)
sequels_year_df = data[['Year', 'Movie Series', 'Order']]

#Drop first movie
sequels_year_df.drop(sequels_year_df[sequels_year_df['Order'] == 1].index, inplace = True)
sequels_year_df.drop('Order', inplace = True, axis = 1)

#Count the number of times the year is mentioned
year_count = sequels_year_df.Year.value_counts()
year_index = year_count.index

fig = px.bar(data, x = year_index, y = year_count, title = 'Each Sequel Title Released per Year', labels={'x': 'Year', 'y':'No. Films'})
fig.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f82a859b-c466-4b29-8806-d72ae9dc8ccd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f82a859b-c466-4b29-8806-d72ae9dc8ccd")) {                    Plotly.newPlot(                        "f82a859b-c466-4b29-8806-d72ae9dc8ccd",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>No. Films=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2011.0,2009.0,2014.0,2007.0,2013.0,2003.0,2004.0,2006.0,2012.0,2010.0,2008.0,2016.0,2017.0,2005.0,2015.0,2019.0,1989.0,2002.0,1990.0,2018.0,1988.0,2000.0,1992.0,1995.0,1994.0,1998.0,1997.0,1999.0,2001.0,1984.0,1986.0,1987.0,1991.0,1985.0,1993.0,1996.0,1981.0,1982.0,1983.0,2020.0,2021.0,2022.0,1979.0,1980.0,1977.0,1975.0,1944.0,1974.0],"xaxis":"x","y":[28,26,24,22,22,19,19,19,19,18,17,17,16,15,13,13,12,12,12,11,10,9,8,8,8,8,7,7,6,6,6,6,5,5,4,4,4,4,4,3,2,2,2,2,2,2,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatte ...

# %% [markdown]
# In the above bar chart you can see the number of different movie sequels produced per year.
# For this graph, I made sure to remove the first movie of the franchise (found using the "Order" column in the database). I did this so that only the continuation of a series is recorded, as when the first movie is released a sequel isn't usually the plan.
# From this graph we can see 2011 had the most sequels produced, with 28 sequels being released.

# %%
print("Sequels made in 2021\n")
print(sequels_year_df[sequels_year_df.Year == 2021])
print("\nSequels made in 2022\n")
print(sequels_year_df[sequels_year_df.Year == 2022])
print("\nSequels made in 1944\n")
print(sequels_year_df[sequels_year_df.Year == 1944])
print("\nSequels made in 1989\n")
print(sequels_year_df[sequels_year_df.Year == 1989])
print("\nSequels made in 1990\n")
print(sequels_year_df[sequels_year_df.Year == 1990])
# Out:
# Sequels made in 2021
#
#        Year             Movie Series
# 247  2021.0  Guardians of the Galaxy
# 415  2021.0                  Mission
#
# Sequels made in 2022
#
#        Year Movie Series
# 340  2022.0    John Wick
# 416  2022.0      Mission
#
# Sequels made in 1944
#
#        Year Movie Series
# 131  1944.0   Cat People
#
# Sequels made in 1989
#
#        Year               Movie Series
# 21   1989.0  A Nightmare on Elm Street
# 64   1989.0         Back to the Future
# 209  1989.0                     Fletch
# 221  1989.0            Friday the 13th
# 236  1989.0               Ghostbusters
# 252  1989.0                  Halloween
# 321  1989.0              Indiana Jones
# 370  1989.0              Lethal Weapon
# 462  1989.0             Police Academy
# 566  1989.0                  Star Trek
# 670  1989.0                    The Fly
# 704  1989.0             The Karate Kid
#
# Sequels made in 1990
#
#        Year        Movie Series
# 10   1990.0             48 Hrs.
# 65   1990.0  Back to the Future
# 137  1990.0        Child's Play
# 174  1990.0            Die Hard
# 244  1990.0            Gremlins
# 376  1990.0  Look Who's Talking
# 468  1990.0            Predator
# 495  1990.0             RoboCop
# 501  1990.0               Rocky
# 658  1990.0        The Exorcist
# 677  1990.0       The Godfather
# 855  1990.0          Young Guns
